# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation

from keras.layers import Input, Dense
from tensorflow.keras.optimizers import SGD

from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd

# %%
veri = pd.read_csv("breast-cancer-wisconsin.data")
#veri.head(10)

veri.replace(to_replace="?",value=-99999,inplace=True)
veriyeni = veri.drop(['1000025'],axis=1)

imp = SimpleImputer(missing_values=-99999, strategy="mean")
veriyeni = imp.fit_transform(veriyeni)

giris = veriyeni[:,0:8]
cikis = veriyeni[:,9]

# %%
model= Sequential()
model.add(Dense(10,input_dim=8))
model.add(layers.Activation(activations.relu))
model.add(Dropout(0.5))

model.add(Dense(10))
model.add(layers.Activation(activations.relu))
model.add(Dropout(0.5))

model.add(Dense(10))
model.add(layers.Activation('softmax'))#ikili sınıflandırma olduğu için sigmoid fonk kullanmalıyız ama Softmax'İ ikili  sınıflandırmada kullanırsak sigmoidle birebir aynı olur   

#optimizer = keras.optimizers.Adam(learning_rate=0.01)
#optimizer = keras.optimizers.Adadelta()
optimizer = keras.optimizers.SGD(learning_rate=0.1)

#learning rate ile epochs araasında ters orantı var.Learning rate düşürdükçe epochs sayısını arttırmalıyız
#Learning rate'i çok yüksek seçersek 0'a yaklaşmaz ve belli değerler arasında salınım yapar.

model.compile(optimizer = optimizer, loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(giris,cikis,epochs=50,batch_size=32,validation_split=0.13)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 1s 20ms/step - loss: 1.2638 - accuracy: 0.6013 - val_loss: 0.6857 - val_accuracy: 0.6374
# Epoch 2/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8427 - accuracy: 0.7232 - val_loss: 0.5028 - val_accuracy: 0.8791
# Epoch 3/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8022 - accuracy: 0.7331 - val_loss: 0.3598 - val_accuracy: 0.9890
# Epoch 4/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6415 - accuracy: 0.8072 - val_loss: 0.2805 - val_accuracy: 0.9560
# Epoch 5/50
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5799 - accuracy: 0.8105 - val_loss: 0.2366 - val_accuracy: 0.9780
# Epoch 6/50
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5167 - accuracy: 0.8287 - val_loss: 0.1984 - val_accuracy: 0.9890
# Epoch 7/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4444 - accuracy: 0.8666 - val_loss: 0.1630 - val_accuracy: 1.0000
# Epoch 8/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5014 - accuracy: 0.8369 - val_loss: 0.1871 - val_accuracy: 0.9890
# Epoch 9/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4956 - accuracy: 0.8402 - val_loss: 0.1696 - val_accuracy: 0.9890
# Epoch 10/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4082 - accuracy: 0.8666 - val_loss: 0.1659 - val_accuracy: 1.0000
# Epoch 11/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4070 - accuracy: 0.8748 - val_loss: 0.1487 - val_accuracy: 0.9890
# Epoch 12/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3711 - accuracy: 0.8896 - val_loss: 0.2246 - val_accuracy: 0.8901
# Epoch 13/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4272 - accuracy: 0.8550 - val_loss: 0.2108 - val_accuracy: 0.9011
# Epoch 14/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3548 - accuracy: 0.8814 - val_loss: 0.1132 - val_accuracy: 0.9890
# Epoch 15/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3423 - accuracy: 0.9044 - val_loss: 0.1017 - val_accuracy: 0.9890
# Epoch 16/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3817 - accuracy: 0.8731 - val_loss: 0.1248 - val_accuracy: 0.9780
# Epoch 17/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3550 - accuracy: 0.8847 - val_loss: 0.1636 - val_accuracy: 0.9451
# Epoch 18/50
# 19/19 [==============================] - 0s 11ms/step - loss: 0.3899 - accuracy: 0.8731 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 19/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3730 - accuracy: 0.8764 - val_loss: 0.0830 - val_accuracy: 0.9890
# Epoch 20/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2655 - accuracy: 0.9094 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 21/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3651 - accuracy: 0.8863 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 22/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4189 - accuracy: 0.8616 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 23/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2919 - accuracy: 0.9143 - val_loss: 0.0781 - val_accuracy: 1.0000
# Epoch 24/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3693 - accuracy: 0.8666 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 25/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3615 - accuracy: 0.8748 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 26/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3201 - accuracy: 0.8979 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 27/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3298 - accuracy: 0.8731 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 28/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4093 - accuracy: 0.8600 - val_loss: 0.0775 - val_accuracy: 0.9890
# Epoch 29/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3077 - accuracy: 0.9077 - val_loss: 0.0771 - val_accuracy: 1.0000
# Epoch 30/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2904 - accuracy: 0.8995 - val_loss: 0.0741 - val_accuracy: 0.9890
# Epoch 31/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2816 - accuracy: 0.9127 - val_loss: 0.0716 - val_accuracy: 1.0000
# Epoch 32/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2585 - accuracy: 0.9127 - val_loss: 0.1331 - val_accuracy: 0.9670
# Epoch 33/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3225 - accuracy: 0.8880 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 34/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2788 - accuracy: 0.9012 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 35/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3496 - accuracy: 0.8814 - val_loss: 0.0697 - val_accuracy: 1.0000
# Epoch 36/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3054 - accuracy: 0.8913 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 37/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3732 - accuracy: 0.8814 - val_loss: 0.1101 - val_accuracy: 0.9890
# Epoch 38/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3169 - accuracy: 0.8863 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 39/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3277 - accuracy: 0.8979 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 40/50
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2703 - accuracy: 0.9259 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 41/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3096 - accuracy: 0.9028 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 42/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3302 - accuracy: 0.8962 - val_loss: 0.1055 - val_accuracy: 0.9780
# Epoch 43/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2408 - accuracy: 0.9308 - val_loss: 0.0660 - val_accuracy: 1.0000
# Epoch 44/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3239 - accuracy: 0.8995 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 45/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3172 - accuracy: 0.9044 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 46/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3145 - accuracy: 0.8979 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 47/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2637 - accuracy: 0.9143 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 48/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3233 - accuracy: 0.8979 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 49/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3172 - accuracy: 0.9028 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 50/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3044 - accuracy: 0.8880 - val_loss: 0.0719 - val_accuracy: 1.0000

# %%
#tahmin = np.array([5,5,5,8,10,8,7,3]).reshape(1,8) #sample 
#print(np.where(tahmin>0,2,4))
